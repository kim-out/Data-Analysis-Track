# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
# 그래프가 출력되지 않는 경우

# %%
plt.title("Plot")
plt.plot([1,4,9,16]) # x축 기본 배열 [0, 1, 2, ..]
plt.show()

# %%
plt.title("x ticks")
plt.plot([10, 20, 30, 40], [1, 4, 9, 16]) # x틱 지정
plt.show()

# %%
font_list = mpl.font_manager.findSystemFonts()
print(font_list)
# Out:
# ['C:\\WINDOWS\\Fonts\\ERASBD.TTF', 'C:\\WINDOWS\\Fonts\\georgiai.ttf', 'C:\\Windows\\Fonts\\SCRIPTBL.TTF', 'C:\\WINDOWS\\Fonts\\OLDENGL.TTF', 'C:\\WINDOWS\\Fonts\\BOOKOSI.TTF', 'C:\\Windows\\Fonts\\NirmalaS.ttf', 'C:\\WINDOWS\\Fonts\\LCALLIG.TTF', 'C:\\WINDOWS\\Fonts\\palai.ttf', 'C:\\Windows\\Fonts\\trebucbi.ttf', 'C:\\WINDOWS\\Fonts\\PERTILI.TTF', 'C:\\Windows\\Fonts\\ariblk.ttf', 'C:\\WINDOWS\\Fonts\\timesi.ttf', 'C:\\WINDOWS\\Fonts\\consolab.ttf', 'C:\\WINDOWS\\Fonts\\constan.ttf', 'C:\\WINDOWS\\Fonts\\SegoeIcons.ttf', 'C:\\WINDOWS\\Fonts\\BOOKOSBI.TTF', 'C:\\Windows\\Fonts\\STXIHEI.TTF', 'C:\\Windows\\Fonts\\LTYPEBO.TTF', 'C:\\WINDOWS\\Fonts\\cambriab.ttf', 'C:\\WINDOWS\\Fonts\\constanb.ttf', 'C:\\Windows\\Fonts\\CALIFR.TTF', 'C:\\WINDOWS\\Fonts\\BOD_I.TTF', 'C:\\WINDOWS\\Fonts\\ERASLGHT.TTF', 'C:\\Windows\\Fonts\\OUTLOOK.TTF', 'C:\\WINDOWS\\Fonts\\OCRAEXT.TTF', 'C:\\WINDOWS\\Fonts\\FRABKIT.TTF', 'C:\\WINDOWS\\Fonts\\segmdl2.ttf', 'C:\\WINDOWS\\Fonts\\DUBAI-BOLD.TTF', 'C:\\WINDO
# ...

# %%
prop = mpl.font_manager.FontProperties(fname = "")
plt.rcParams['font.family'] = prop.get_family()

# %%
# !sudo apt install -y fonts_nanum*
# !sudo fc_cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# 'sudo'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.
# 'sudo'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.
# 'rm'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.

# %%
import matplotlib as mpl
# Add every font at the specified location
font_dir = ['./fonts']
for font in mpl.font_manager.findSystemFonts(fontpaths=font_dir):
    print(mpl.font_manager.FontProperties(fname=font).get_name())
    mpl.font_manager.fontManager.addfont(font)
# Set font family globally
mpl.rcParams['font.family'] = 'Noto Sans KR'
print(mpl.rcParams['font.family'])
# Out:
# NanumSquare Neo Light
# NanumBarunGothic YetHangul
# NanumSquare Neo Regular
# NanumBarunGothic
# NanumSquare Neo OTF Bold
# NanumSquareRound
# NanumSquare Neo ExtraBold
# NanumSquareOTF_ac
# NanumGothicOTF
# NanumGothic
# NanumSquareOTF
# NanumGothic Eco
# NanumSquare
# NanumBarunGothic
# NanumBarunGothic
# NanumGothicOTF Eco
# NanumMyeongjo Eco
# NanumSquare Neo OTF Light
# NanumBarunpen
# NanumSquare Neo OTF Heavy
# NanumSquare_ac
# NanumMyeongjoOTF
# Nanum Brush Script OTF
# NanumGothic Eco
# NanumBarunGothicOTF
# NanumSquare Neo OTF Regular
# NanumGothicOTF
# NanumGothic
# NanumSquare Neo Heavy
# NanumSquareOTF
# D2Coding ligature
# NanumBarunGothicOTF
# NanumSquareOTF
# NanumMyeongjo Eco
# D2Coding
# NanumMyeongjoOTF Eco
# NanumSquareOTF_ac
# NanumBarunpenOTF
# NanumGothic
# NanumMyeongjo
# NanumSquareRound
# NanumBarunGothic
# NanumGothicOTF
# NanumGothic
# NanumSquareOTF
# Nanum Pen Script OTF
# NanumMyeongjoOTF YetHangul
# NanumBarunGothicOTF
# NanumMyeongjoOTF
# ...

# %%
# 폰트 설정
global_font = {'family' : 'NanumGothicOTF', 'size':12, 'weight': 'bold'}
mpl.rc('font', **global_font)

# %%
#유니코드에서 음수 부호 설정
mpl.rc('axes', unicode_minus=False)

# %%
import numpy as np
X =np.linspace(-np.pi, np.pi, 256)
C, S = np.cos(X), np.sin(X)
plt.title("legend plot")
plt.plot(X, C, ls = "--", label= "cosine")
plt.plot(X, S, ls = ":", label= "sine")
plt.legend(loc=2) #upper left
plt.show()

# %%
X =np.linspace(-np.pi, np.pi, 256)
C, S = np.cos(X), np.sin(X)
plt.title("cosine plot")
plt.plot(X,C,label = "cosine")
plt.xlabel("time")
plt.ylabel("amplitude")

plt.show()

# %%
plt.title("섭씨 온도와 화씨 온도")
plt.xlabel("화씨 온도")
plt.ylabel("섭씨 온도")
X= [ _ for _ in range(32, 100)]
Y = [(a - 32) * (5/9) for a in X]
plt.plot(X,Y, ls = "-.", c = "r")

# %% [markdown]
# - 그래프 구성
# https://matplotlib.org/stable/tutorials/introductory/quick_start.html#parts-of-a-figure

# %%
fig, ax = plt.subplots() # axes를 포함하는 figure 객체 생성
# figure -> 전체 그래프를 의미하는 객체, 캔버스
ax.plot([1,2,3,4], [1,4,2,3])
fig

# %%
fig = plt.figure() # 빈 figure
fig, ax = plt.subplots() # 하나의 axes를 가진 figure
fig, axs = plt.subplots(2, 2) # 해당 shape의 axes를 갖는 figure 생성

# %%
np.random.seed(0)
f1 = plt.figure(figsize = (10, 2)) # figsixe -> 그림 크기
plt.title("figure size : (10, 2)")
plt.plot(np.random.randn(100))
plt.show()

# %%
f1 = plt.figure(1)
plt.title("현재의 Figure 객체")
plt.plot([1, 2, 3, 4], 'ro:')

f2 = plt.gcf()
print(f1, id(f1))
print(f2, id(f2))
plt.show()
# Out:
# Figure(640x480) 2763990867008
# Figure(640x480) 2763990867008

# %%
ax1 = plt.subplot(2, 1, 1) # (행렬 모양, 순서)
ax2 = plt.subplot(2, 1, 2)

# %%
x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)
y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

ax1 = plt.subplot(2, 1, 1)
plt.plot(x1, y1, 'yo-')
plt.title('A tale of 2 subplots')
plt.ylabel('Damped oscillation')

ax2 = plt.subplot(2, 1, 2)
plt.plot(x2, y2, 'r.-')
plt.xlabel('time (s)')
plt.ylabel('Undamped')

plt.tight_layout() # 플롯 간 간격 자동 맞춤
plt.show()

# %%
np.random.seed(0) #subplot이용

plt.subplot(221) # subplots(2,2,1)
plt.plot(np.random.rand(5))
plt.title("axes 1")

plt.subplot(222)
plt.plot(np.random.rand(5))
plt.title("axes 2")

plt.subplot(223)
plt.plot(np.random.rand(5))
plt.title("axes 3")

plt.subplot(224)
plt.plot(np.random.rand(5))
plt.title("axes 4")

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2, 2) #subplot's'이용

np.random.seed(0)
axes[0,0].plot(np.random.rand(5))
axes[0,0].set_title("axes 1")
axes[0,1].plot(np.random.rand(5))
axes[0,1].set_title("axes 2")
axes[1,0].plot(np.random.rand(5))
axes[1,0].set_title("axes 3")
axes[1,1].plot(np.random.rand(5))
axes[1,1].set_title("axes 4")

plt.tight_layout()
plt.show()

# %% [markdown]
# - Axes 플롯
# - Axis 축

# %%
fig,ax0 = plt.subplots()
ax1 = ax0.twinx() # x축을 공유하는 axes객체 생성성

ax0.set_title("2개의 y축 한 figure에서 사용하기")
ax0.plot([10, 5, 2, 9, 7], '-r', label = 'y0')
ax0.set_ylabel("y0")
ax0.grid(False)
ax1.plot([100, 200, 220, 180, 120], 'g:', label = "y1")
ax1.set_ylabel("y1")
ax1.grid(False)
ax0.set_xlabel("공유되는 x축")
plt.show()

# %% [markdown]
# # Bar Chart

# %%
# 바 차트
y = [2, 3, 1]
x = ['가', '나', '다']
plt.title("Bar Chart") 
plt.bar(x, y) # barh 사용 시 가로 방향으로 그림
plt.xlabel("가나다")
plt.ylabel("빈도 수")
plt.show()

# %%
y = [2, 3, 1]
x = ['가', '나', '다']
colors = ['red', 'green', 'blue']
          
plt.title("Bar Chart") 
plt.bar(x, y, color = colors)
plt.xlabel("가나다")
plt.ylabel("빈도 수")
plt.show()

# %%
np.random.seed(0)

people = ['몽룡', '춘향', '방자', '향단']
performance = 3 + 10 * np.random.rand(len(people))
error = np.random.rand(len(people))

plt.title("Barh Chart")
plt.barh(people, performance, xerr = error, alpha = 0.4)
# xerr, yerr : 에러 바
# alpha : 투명도(0-투명, 1-불투명)

plt.xlabel('x 라벨')
plt.show()

# %%
import seaborn as sns
titanic = sns.load_dataset("titanic")
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
len(titanic) -titanic.survived.sum()
# Out:
# 549

# %%
bar_chart = titanic["alive"].value_counts()
bar_chart.rename({'no':'사망자', 'yes':'생존자'}, inplace = True)
bar_chart
# Out:
# 사망자    549
# 생존자    342
# Name: alive, dtype: int64

# %%
alive = bar_chart.index
value = bar_chart.values
bar_colors = ['red','green']
plt.title('타이타닉호 생존 여부')
plt.barh(alive, value, color = bar_colors)
plt.xlabel('인원 수')
plt.show()

# %% [markdown]
# # Pie Chart

# %%
labels = ['월세', '전세', '자가', '기타']
sizes = [15, 30, 45, 10]
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
explode = (0, 0, 0.1, 0)
plt.title("Pie Chart")
plt.pie(sizes, explode = explode, labels = labels, colors = colors,
        autopct = '%1.1f%%', shadow = True, startangle=90)
plt.axis('equal') #원의 형태를 유지
plt.show()

# %%
import pandas as pd
bins = [0, 20, 30, 50, 70, 100]
labels = ["미성년자", "청년", "장년", "중년", "노년"]
explode = (0.1, 0, 0, 0, 0)
colors = ["yellowgreen", "gold", "lightskyblue", "lightcoral", "orange"]

ages = titanic.age.dropna()
ages_char = pd.cut(ages, bins, labels = labels).value_counts(True)

plt.pie(ages_char, explode = explode, labels = ages_char.index, colors = colors, # 라벨 인덱스 주의
        autopct = '%1.1f%%', shadow = True, startangle=90)
plt.show()

# %% [markdown]
# # Histogram

# %%
np.random.seed(0)
x = np.random.randn(1000)
plt.title("Histogram")
arrays, bins, patches = plt.hist(x, bins = 10)
plt.show()

# %%
arrays
# Out:
# array([  9.,  20.,  70., 146., 217., 239., 160.,  86.,  38.,  15.])

# %%
bins
# Out:
# array([-3.04614305, -2.46559324, -1.88504342, -1.3044936 , -0.72394379,
#        -0.14339397,  0.43715585,  1.01770566,  1.59825548,  2.1788053 ,
#         2.75935511])

# %%
patches
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# # Scatter Plot

# %%
np.random.seed(0)
x = np.random.normal(0, 1, 100)
y = np.random.normal(0, 1, 100)
plt.title("Scatter Plot")
plt.scatter(x, y)
plt.show()

# %%
N = 30
np.random.seed(0)
x = np.random.rand(N)
y1 = np.random.rand(N)
y2 = np.random.rand(N)
y3 = np.pi * (15 * np.random.rand(N)) ** 2
plt.title("Bubble Chart")
plt.scatter(x, y1, c=y2, s=y3)
plt.show()

# %%
from sklearn.datasets import load_digits
digits = load_digits()
x = digits.images[0]
x
# Out:
# array([[ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.],
#        [ 0.,  0., 13., 15., 10., 15.,  5.,  0.],
#        [ 0.,  3., 15.,  2.,  0., 11.,  8.,  0.],
#        [ 0.,  4., 12.,  0.,  0.,  8.,  8.,  0.],
#        [ 0.,  5.,  8.,  0.,  0.,  9.,  8.,  0.],
#        [ 0.,  4., 11.,  0.,  1., 12.,  7.,  0.],
#        [ 0.,  2., 14.,  5., 10., 12.,  0.,  0.],
#        [ 0.,  0.,  6., 13., 10.,  0.,  0.,  0.]])

# %% [markdown]
# # imshow

# %%
plt.title("mnlist digits; 0")
plt.imshow(x, interpolation='nearest', cmap=plt.cm.bone_r)
# cmap -> 컬러맵
plt.xticks([])
plt.yticks([])
plt.grid(False)
plt.subplots_adjust(left = 0.35, right = 0.65, bottom = 0.35, top = 0.65)
plt.show()

# %%
dir(plt.cm)[:10] #컬러맵 확인
# plt.cm -> 컬러맵
# Out:
# ['Accent',
#  'Accent_r',
#  'Blues',
#  'Blues_r',
#  'BrBG',
#  'BrBG_r',
#  'BuGn',
#  'BuGn_r',
#  'BuPu',
#  'BuPu_r']

# %%
fig, axes = plt.subplots(1, 4, figsize = (12, 3),
                         subplot_kw = {'xticks':[], 'yticks':[]})
axes[0].set_title("plt.cm.Blues")
axes[0].imshow(x, interpolation='nearest', cmap=plt.cm.Blues)
axes[1].set_title("plt.cm.Blues_r")
axes[1].imshow(x, interpolation='nearest', cmap=plt.cm.Blues_r)   
axes[2].set_title("plt.BrBG")
axes[2].imshow(x, interpolation='nearest', cmap=plt.cm.BrBG)
axes[3].set_title("plt.BrBG_r")
axes[3].imshow(x, interpolation='nearest', cmap=plt.cm.BrBG_r)

# %%
methods = {
    None, 'none', 'nearest', 'bilinear', 'bicubic', 'spline16', 'spline36',
    'hanning', 'hamming', 'hermite', 'kaiser', 'quadric', 'catrom', 'gaussian',
    'bessel', 'mitchell', 'sinc', 'lanczos'
}
fig, axes = plt.subplots(3, 6, figsize = (12, 6),
                         subplot_kw = {'xticks' : [], 'yticks' : []})
for ax, interp_method in zip(axes.flat, methods):
    ax.imshow(x, cmap = plt.cm.bone_r, interpolation = interp_method)
    ax.set_title(interp_method)
    
plt.show()

# %%
def f(x,y):
    return (1-x/2+x**5+y**3) * np.exp(-x ** 2 - y ** 2)

n = 256
x = np.linspace(-3, 3, n)
y = np.linspace(-3, 3, n)
xx, yy = np.meshgrid(x, y)
zz = f(xx, yy)

plt.title("Contour plots")
plt.contourf(xx, yy, zz, alpha = .75, cmap = 'jet')
plt.contour(xx, yy, zz, colors = 'black')
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
x = np.arange(-4, 4, 0.25)
y = np.arange(-4, 4, 0.25)

xx, yy = np.meshgrid(x, y)
rr = np.sqrt(xx**2 + yy**2)
zz = np.sin(rr)

fig = plt.figure()
ax = Axes3D(fig)
ax.set_title("3D Surface Plot")
ax.plot_surface(xx, yy, zz, rstride = 1, cstride=1, cmap='hot')
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_17748\3155042837.py:10: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)
