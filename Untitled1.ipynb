# %% [markdown]
# ![image.png](attachment:863d9343-9947-49ee-a2c0-eb4c7682f788.png)

# %%
n,k = map(int,input().split(' '))
stuff = [[0,0]]
bag = [[0]*(k+1) for i in range(n+1)]
for i in range(n):
    stuff.append(list(map(int,input().split(' '))))
for i in range(n+1):
    for j in range(
# Out:
#  3 3
#  3 2
#  2 3
#  23 4

# %%
# Out:
# [[0, 0], [3, 2], [2, 3], [23, 4]]
