# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
titanic = pd.read_csv("https://storage.googleapis.com/tf-datasets/titanic/train.csv")
titanic = sns.load_dataset("https://storage.googleapis.com/tf-datasets/titanic/train.csv")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6528\3018676764.py in <module>
#       1 titanic = pd.read_csv("https://storage.googleapis.com/tf-datasets/titanic/train.csv")
# ----> 2 titanic = sns.load_dataset("https://storage.googleapis.com/tf-datasets/titanic/train.csv")
#
# ~\anaconda3\lib\site-packages\seaborn\utils.py in load_dataset(name, cache, data_home, **kws)
#     593         if not os.path.exists(cache_path):
#     594             if name not in get_dataset_names():
# --> 595                 raise ValueError(f"'{name}' is not one of the example datasets.")
#     596             urlretrieve(url, cache_path)
#     597         full_path = cache_path
#
# ValueError: 'https://storage.googleapis.com/tf-datasets/titanic/train.csv' is not one of the example datasets.

# %%
titanic
# Out:
#      survived     sex   age  n_siblings_spouses  parch     fare   class  \
# 0           0    male  22.0                   1      0   7.2500   Third
# 1           1  female  38.0                   1      0  71.2833   First
# 2           1  female  26.0                   0      0   7.9250   Third
# 3           1  female  35.0                   1      0  53.1000   First
# 4           0    male  28.0                   0      0   8.4583   Third
# ..        ...     ...   ...                 ...    ...      ...     ...
# 622         0    male  28.0                   0      0  10.5000  Second
# 623         0    male  25.0                   0      0   7.0500   Third
# 624         1  female  19.0                   0      0  30.0000   First
# 625         0  female  28.0                   1      2  23.4500   Third
# 626         0    male  32.0                   0      0   7.7500   Third
#
#         deck  embark_town alone
# 0    unknown  Southampton     n
# 1          C    Cherbourg     n
# ...

# %%
titanic.head(10)
# Out:
#    survived     sex   age  n_siblings_spouses  parch     fare   class  \
# 0         0    male  22.0                   1      0   7.2500   Third
# 1         1  female  38.0                   1      0  71.2833   First
# 2         1  female  26.0                   0      0   7.9250   Third
# 3         1  female  35.0                   1      0  53.1000   First
# 4         0    male  28.0                   0      0   8.4583   Third
# 5         0    male   2.0                   3      1  21.0750   Third
# 6         1  female  27.0                   0      2  11.1333   Third
# 7         1  female  14.0                   1      0  30.0708  Second
# 8         1  female   4.0                   1      1  16.7000   Third
# 9         0    male  20.0                   0      0   8.0500   Third
#
#       deck  embark_town alone
# 0  unknown  Southampton     n
# 1        C    Cherbourg     n
# 2  unknown  Southampton     y
# 3        C  Southampton     n
# 4  unknown   Queenstown     y
# ...

# %%
import seaborn as sns

# %%
titanic =sns.load_dataset("titanic")
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.sample(3) # 임의의 행 추출
# Out:
#      survived  pclass     sex    age  sibsp  parch    fare embarked  class  \
# 654         0       3  female  18.00      0      0  6.7500        Q  Third
# 815         0       1    male    NaN      0      0  0.0000        S  First
# 803         1       3    male   0.42      0      1  8.5167        C  Third
#
#        who  adult_male deck  embark_town alive  alone
# 654  woman       False  NaN   Queenstown    no   True
# 815    man        True    B  Southampton    no   True
# 803  child       False  NaN    Cherbourg   yes  False

# %%
titanic.nunique() # 각 컬럼이 갖는 고유한 값
# Out:
# survived         2
# pclass           3
# sex              2
# age             88
# sibsp            7
# parch            7
# fare           248
# embarked         3
# class            3
# who              3
# adult_male       2
# deck             7
# embark_town      3
# alive            2
# alone            2
# dtype: int64

# %%
titanic.count() # 각 컬럼 별 nan값 배제한 개수
# Out:
# survived       891
# pclass         891
# sex            891
# age            714
# sibsp          891
# parch          891
# fare           891
# embarked       889
# class          891
# who            891
# adult_male     891
# deck           203
# embark_town    889
# alive          891
# alone          891
# dtype: int64

# %%
len(titanic) # 전체 자료의 길이
# Out:
# 891

# %%
titanic.dtypes # category 범주화된 데이터, 메모리 절약
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
titanic.sum(numeric_only = True) # numeric only -> 수치형 자료만 연산
# Out:
# survived        342.0000
# pclass         2057.0000
# age           21205.1700
# sibsp           466.0000
# parch           340.0000
# fare          28693.9493
# adult_male      537.0000
# alone           537.0000
# dtype: float64

# %%
titanic.mean(numeric_only = True)
# Out:
# survived       0.383838
# pclass         2.308642
# age           29.699118
# sibsp          0.523008
# parch          0.381594
# fare          32.204208
# adult_male     0.602694
# alone          0.602694
# dtype: float64

# %%
titanic.median(numeric_only = True)
# Out:
# survived       0.0000
# pclass         3.0000
# age           28.0000
# sibsp          0.0000
# parch          0.0000
# fare          14.4542
# adult_male     1.0000
# alone          1.0000
# dtype: float64

# %%
titanic.std(numeric_only = True)
# Out:
# survived       0.486592
# pclass         0.836071
# age           14.526497
# sibsp          1.102743
# parch          0.806057
# fare          49.693429
# adult_male     0.489615
# alone          0.489615
# dtype: float64

# %%
titanic[["age", "fare", "survived"]].sum(axis="rows")
# Out:
# age         21205.1700
# fare        28693.9493
# survived      342.0000
# dtype: float64

# %%
titanic[["age", "fare", "survived"]].sum(axis=0)
# Out:
# age         21205.1700
# fare        28693.9493
# survived      342.0000
# dtype: float64

# %%
titanic[["age", "fare", "survived"]].sum(axis="columns")
# Out:
# 0       29.2500
# 1      110.2833
# 2       34.9250
# 3       89.1000
# 4       43.0500
#          ...
# 886     40.0000
# 887     50.0000
# 888     23.4500
# 889     57.0000
# 890     39.7500
# Length: 891, dtype: float64

# %%
titanic[["age", "fare", "survived"]].sum(axis=1)
# Out:
# 0       29.2500
# 1      110.2833
# 2       34.9250
# 3       89.1000
# 4       43.0500
#          ...
# 886     40.0000
# 887     50.0000
# 888     23.4500
# 889     57.0000
# 890     39.7500
# Length: 891, dtype: float64

# %%
titanic.nlargest(3,columns = ["fare","age"])
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 679         1       1    male  36.0      0      1  512.3292        C  First
# 258         1       1  female  35.0      0      0  512.3292        C  First
# 737         1       1    male  35.0      0      0  512.3292        C  First
#
#        who  adult_male deck embark_town alive  alone
# 679    man        True    B   Cherbourg   yes  False
# 258  woman       False  NaN   Cherbourg   yes   True
# 737    man        True    B   Cherbourg   yes   True

# %%
titanic.nsmallest(3,columns = ["age"])
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 803         1       3    male  0.42      0      1   8.5167        C   Third
# 755         1       2    male  0.67      1      1  14.5000        S  Second
# 469         1       3  female  0.75      2      1  19.2583        C   Third
#
#        who  adult_male deck  embark_town alive  alone
# 803  child       False  NaN    Cherbourg   yes  False
# 755  child       False  NaN  Southampton   yes  False
# 469  child       False  NaN    Cherbourg   yes  False

# %%
titanic.describe() # 수치형 데이터만 요약
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
nba = pd.read_csv("datas/nba.csv", parse_dates = ["Birthday"])
nba
# Out:
#                Name                 Team Position   Birthday    Salary
# 0      Shake Milton   Philadelphia 76ers       SG 1996-09-26   1445697
# 1    Christian Wood      Detroit Pistons       PF 1995-09-27   1645357
# 2     PJ Washington    Charlotte Hornets       PF 1998-08-23   3831840
# 3      Derrick Rose      Detroit Pistons       PG 1988-10-04   7317074
# 4     Marial Shayok   Philadelphia 76ers        G 1995-07-26     79568
# ..              ...                  ...      ...        ...       ...
# 445   Austin Rivers      Houston Rockets       PG 1992-08-01   2174310
# 446     Harry Giles     Sacramento Kings       PF 1998-04-22   2578800
# 447     Robin Lopez      Milwaukee Bucks        C 1988-04-01   4767000
# 448   Collin Sexton  Cleveland Cavaliers       PG 1999-01-04   4764960
# 449     Ricky Rubio         Phoenix Suns       PG 1990-10-21  16200000
#
# [450 rows x 5 columns]

# %%
nba.dtypes
# Out:
# Name                object
# Team                object
# Position            object
# Birthday    datetime64[ns]
# Salary               int64
# dtype: object

# %%
nba.dtypes.value_counts()
# Out:
# object            3
# datetime64[ns]    1
# int64             1
# dtype: int64

# %%
nba.columns
nba.index
# Out:
# RangeIndex(start=0, stop=450, step=1)

# %%
nba.shape
nba.ndim
# Out:
# 2

# %%
nba.isnull()
# Out:
#       Name   Team  Position  Birthday  Salary
# 0    False  False     False     False   False
# 1    False  False     False     False   False
# 2    False  False     False     False   False
# 3    False  False     False     False   False
# 4    False  False     False     False   False
# ..     ...    ...       ...       ...     ...
# 445  False  False     False     False   False
# 446  False  False     False     False   False
# 447  False  False     False     False   False
# 448  False  False     False     False   False
# 449  False  False     False     False   False
#
# [450 rows x 5 columns]

# %%
nba.isna().sum(axis=0)
# Out:
# Name        0
# Team        0
# Position    0
# Birthday    0
# Salary      0
# dtype: int64

# %%
nba.count().sum()
# Out:
# 2250

# %%
nba
# Out:
#                Name                 Team Position   Birthday    Salary
# 0      Shake Milton   Philadelphia 76ers       SG 1996-09-26   1445697
# 1    Christian Wood      Detroit Pistons       PF 1995-09-27   1645357
# 2     PJ Washington    Charlotte Hornets       PF 1998-08-23   3831840
# 3      Derrick Rose      Detroit Pistons       PG 1988-10-04   7317074
# 4     Marial Shayok   Philadelphia 76ers        G 1995-07-26     79568
# ..              ...                  ...      ...        ...       ...
# 445   Austin Rivers      Houston Rockets       PG 1992-08-01   2174310
# 446     Harry Giles     Sacramento Kings       PF 1998-04-22   2578800
# 447     Robin Lopez      Milwaukee Bucks        C 1988-04-01   4767000
# 448   Collin Sexton  Cleveland Cavaliers       PG 1999-01-04   4764960
# 449     Ricky Rubio         Phoenix Suns       PG 1990-10-21  16200000
#
# [450 rows x 5 columns]

# %%
nba.max()
nba.min()
# Out:
# Name               Aaron Gordon
# Team              Atlanta Hawks
# Position                      C
# Birthday    1977-01-26 00:00:00
# Salary                    79568
# dtype: object

# %%
nba.nunique()
# Out:
# Name        450
# Team         30
# Position      9
# Birthday    430
# Salary      269
# dtype: int64

# %%
nba[nba["Name"] == "Zylan Cheatham"]
# Out:
#                Name                  Team Position   Birthday  Salary
# 248  Zylan Cheatham  New Orleans Pelicans       SF 1995-11-17   79568

# %%
nba.nlargest(5,columns = ["Salary"])
# Out:
#                   Name                   Team Position   Birthday    Salary
# 205      Stephen Curry  Golden State Warriors       PG 1988-03-14  40231758
# 38          Chris Paul  Oklahoma City Thunder       PG 1985-05-06  38506482
# 219  Russell Westbrook        Houston Rockets       PG 1988-11-12  38506482
# 251          John Wall     Washington Wizards       PG 1990-09-06  38199000
# 264       James Harden        Houston Rockets       PG 1989-08-26  38199000

# %%
nba.nsmallest(5,columns = ["Birthday"])
# Out:
#                Name               Team Position   Birthday    Salary
# 98     Vince Carter      Atlanta Hawks       PF 1977-01-26   2564753
# 196   Udonis Haslem         Miami Heat        C 1980-06-09   2564753
# 262     Kyle Korver    Milwaukee Bucks       PF 1981-03-17   6004753
# 149  Tyson Chandler    Houston Rockets        C 1982-10-02   2564753
# 415  Andre Iguodala  Memphis Grizzlies       SF 1984-01-28  17185185

# %%
nba[["Salary"]].sum()
nba[["Salary"]].mean()
nba[["Salary"]].median()
nba[["Salary"]].std()
# Out:
# Salary    9.288810e+06
# dtype: float64

# %%
titanic.sort_values("fare") # fare를 기준으로 정렬
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 271         1       3    male  25.0      0      0    0.0000        S   Third
# 597         0       3    male  49.0      0      0    0.0000        S   Third
# 302         0       3    male  19.0      0      0    0.0000        S   Third
# 633         0       1    male   NaN      0      0    0.0000        S   First
# 277         0       2    male   NaN      0      0    0.0000        S  Second
# ..        ...     ...     ...   ...    ...    ...       ...      ...     ...
# 438         0       1    male  64.0      1      4  263.0000        S   First
# 341         1       1  female  24.0      3      2  263.0000        S   First
# 737         1       1    male  35.0      0      0  512.3292        C   First
# 258         1       1  female  35.0      0      0  512.3292        C   First
# 679         1       1    male  36.0      0      1  512.3292        C   First
#
# ...

# %%
titanic.sort_index(ascending = False)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 0           0       3    male  22.0      1      0   7.2500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.sort_index(axis = 1)
# Out:
#      adult_male   age alive  alone   class deck  embark_town embarked  \
# 0          True  22.0    no  False   Third  NaN  Southampton        S
# 1         False  38.0   yes  False   First    C    Cherbourg        C
# 2         False  26.0   yes   True   Third  NaN  Southampton        S
# 3         False  35.0   yes  False   First    C  Southampton        S
# 4          True  35.0    no   True   Third  NaN  Southampton        S
# ..          ...   ...   ...    ...     ...  ...          ...      ...
# 886        True  27.0    no   True  Second  NaN  Southampton        S
# 887       False  19.0   yes   True   First    B  Southampton        S
# 888       False   NaN    no  False   Third  NaN  Southampton        S
# 889        True  26.0   yes   True   First    C    Cherbourg        C
# 890        True  32.0    no   True   Third  NaN   Queenstown        Q
#
#         fare  parch  pclass     sex  sibsp  survived    who
# 0     7.2500      0       3    male      1         0    man
# ...

# %%
titanic[["sex"]].value_counts()
# Out:
# sex
# male      577
# female    314
# dtype: int64

# %%
titanic[["age"]].value_counts()
# Out:
# age
# 24.00    30
# 22.00    27
# 18.00    26
# 30.00    25
# 28.00    25
#          ..
# 20.50     1
# 14.50     1
# 12.00     1
# 0.92      1
# 80.00     1
# Length: 88, dtype: int64

# %%
titanic[["class"]].value_counts()
# Out:
# class
# Third     491
# First     216
# Second    184
# dtype: int64

# %%
titanic[["alive"]].value_counts()
# Out:
# alive
# no       549
# yes      342
# dtype: int64

# %%
df = pd.DataFrame(np.arange(10,22).reshape(3,4),
             index = list("abc"),
             columns = list("ABCD"),
             )

# %%
df.loc["a"] # row index label
# Out:
# A    10
# B    11
# C    12
# D    13
# Name: a, dtype: int32

# %%
df["b":"c"]
# Out:
#     A   B   C   D
# b  14  15  16  17
# c  18  19  20  21

# %%
df.loc[["b","c"]]
# Out:
#     A   B   C   D
# b  14  15  16  17
# c  18  19  20  21

# %%
df.loc[df.A > 15]
# Out:
#     A   B   C   D
# c  18  19  20  21

# %%
def select_rows(df, num):
    return df.A > num

select_rows(df, 10)
# Out:
# a    False
# b     True
# c     True
# Name: A, dtype: bool

# %%
df.loc[select_rows(df, 10)]
# Out:
#     A   B   C   D
# b  14  15  16  17
# c  18  19  20  21

# %% [markdown]
# # loc, iloc

# %%
df.loc["b": "A"]
df.loc["a",:]
df.loc[["a","b"],["B","D"]]

# %%
df.loc[df.A >10,["C","D"]] # [ 행 조건, 열 조건]

# %%
df.iloc[0,1] # 정수만 인덱스로 받는  loc

# %%
df.iloc[:2,2]

# %%
df.iloc[-1] = df.iloc[-1] * 2
df

# %%
titanic

# %%
round(titanic["age"].mean(),1)

# %%
round(titanic[titanic.sex=="female"]["age"].mean(),1)

# %%
round(titanic[(titanic.pclass == 1) & (titanic.sex == "female")]["age"].mean(),1)

# %%
nba.nlargest(1, columns = ["Salary"])
# Out:
#               Name                   Team Position   Birthday    Salary
# 205  Stephen Curry  Golden State Warriors       PG 1988-03-14  40231758

# %% [markdown]
# # at, iat

# %%
nba = pd.read_csv("datas/nba.csv", index_col = "Name")

# %%
# %%timeit
nba.at["Stephen Curry", "Birthday"]
# Out:
# 3.46 µs ± 128 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# %%timeit
nba.loc["Stephen Curry", "Birthday"]
# Out:
# 6.38 µs ± 182 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# %%timeit
nba.iat[263,1]
# Out:
# 9.96 µs ± 278 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# %%timeit
nba.iloc[263,1]
# Out:
# 14.1 µs ± 596 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
nba.Salary.loc["Damian Lillard"]
# Out:
# 29802321

# %%
nba.Salary.at["Damian Lillard"]
# Out:
# 29802321

# %%
nba.Salary.iloc[234]
# Out:
# 2033160

# %%
nba.Salary.iat[234]
# Out:
# 2033160

# %%
nba.columns
# Out:
# Index(['Name', 'Team', 'Position', 'Birthday', 'Salary'], dtype='object')

# %%
nba.columns = ["Team", "Position", "Date of Birth", "Pay"]

# %%
nba.head(1)
# Out:
#                             Team Position Date of Birth      Pay
# Name
# Shake Milton  Philadelphia 76ers       SG       9/26/96  1445697

# %%
nba.rename(columns = {"Date of Birth" : "Birthday",
                      "Pay" : "Salary"})
# Out:
#                                Team Position  Birthday    Salary
# Name
# Shake Milton     Philadelphia 76ers       SG   9/26/96   1445697
# Christian Wood      Detroit Pistons       PF   9/27/95   1645357
# PJ Washington     Charlotte Hornets       PF   8/23/98   3831840
# Derrick Rose        Detroit Pistons       PG   10/4/88   7317074
# Marial Shayok    Philadelphia 76ers        G   7/26/95     79568
# ...                             ...      ...       ...       ...
# Austin Rivers       Houston Rockets       PG    8/1/92   2174310
# Harry Giles        Sacramento Kings       PF   4/22/98   2578800
# Robin Lopez         Milwaukee Bucks        C    4/1/88   4767000
# Collin Sexton   Cleveland Cavaliers       PG    1/4/99   4764960
# Ricky Rubio            Phoenix Suns       PG  10/21/90  16200000
#
# [450 rows x 4 columns]

# %%
nba.loc["Giannis Antetokounmpo"]
# Out:
# Team             Milwaukee Bucks
# Position                      PF
# Date of Birth            12/6/94
# Pay                     25842697
# Name: Giannis Antetokounmpo, dtype: object

# %%
nba = nba.rename(index = {"Giannis Antetokounmpo":"Greek Freak"})

# %%
nba.loc["Greek Freak"]
# Out:
# Team             Milwaukee Bucks
# Position                      PF
# Date of Birth            12/6/94
# Pay                     25842697
# Name: Greek Freak, dtype: object

# %%
nfl = pd.read_csv("datas/nfl.csv",parse_dates = ["Birthday"],index_col = "Name")

# %%
nfl
# Out:
#                                     Team Position   Birthday   Salary
# Name
# Tremon Smith         Philadelphia Eagles       RB 1996-07-20   570000
# Shawn Williams        Cincinnati Bengals       SS 1991-05-13  3500000
# Adam Butler         New England Patriots       DT 1994-04-12   645000
# Derek Wolfe               Denver Broncos       DE 1990-02-24  8000000
# Jake Ryan           Jacksonville Jaguars      OLB 1992-02-27  1000000
# ...                                  ...      ...        ...      ...
# Bashaud Breeland      Kansas City Chiefs       CB 1992-01-30   805000
# Craig James          Philadelphia Eagles       CB 1996-04-29   570000
# Jonotthan Harrison         New York Jets        C 1991-08-25  1500000
# Chuma Edoga                New York Jets       OT 1997-05-25   495000
# Tajae Sharpe            Tennessee Titans       WR 1994-12-23  2025000
#
# [1655 rows x 4 columns]

# %%
nfl["Team"].value_counts()
# Out:
# New York Jets           58
# Kansas City Chiefs      56
# Washington Redskins     56
# New Orleans Saints      55
# San Francisco 49Ers     55
# Denver Broncos          54
# Minnesota Vikings       54
# Los Angeles Chargers    54
# Seattle Seahawks        53
# Dallas Cowboys          53
# Buffalo Bills           53
# Atlanta Falcons         53
# Detroit Lions           53
# Chicago Bears           53
# Los Angeles Rams        52
# New York Giants         52
# Philadelphia Eagles     52
# Houston Texans          52
# Arizona Cardinals       51
# Cincinnati Bengals      51
# Green Bay Packers       51
# Oakland Raiders         51
# Jacksonville Jaguars    50
# Cleveland Browns        49
# Miami Dolphins          49
# Indianapolis Colts      49
# Carolina Panthers       49
# New England Patriots    49
# Baltimore Ravens        48
# Pittsburgh Steelers     47
# Tampa Bay Buccaneers    47
# Tennessee Titans        46
# Name: Team, dtype: int64

# %%
nfl.nlargest(5, ["Salary"])
# Out:
#                                  Team Position   Birthday    Salary
# Name
# Kirk Cousins        Minnesota Vikings       QB 1988-08-19  27500000
# Marcus Mariota       Tennessee Titans       QB 1993-10-30  20922000
# Jameis Winston   Tampa Bay Buccaneers       QB 1994-01-06  20922000
# Derek Carr            Oakland Raiders       QB 1991-03-28  19900000
# Jimmy Garoppolo   San Francisco 49Ers       QB 1991-11-02  17200000

# %%
nfl.sort_values(["Team","Salary"],ascending =[True, False])
# Out:
#                                    Team Position   Birthday    Salary
# Name
# Chandler Jones        Arizona Cardinals      OLB 1990-02-27  16500000
# Patrick Peterson      Arizona Cardinals       CB 1990-07-11  11000000
# Larry Fitzgerald      Arizona Cardinals       WR 1983-08-31  11000000
# David Johnson         Arizona Cardinals       RB 1991-12-16   5700000
# Justin Pugh           Arizona Cardinals        G 1990-08-15   5000000
# ...                                 ...      ...        ...       ...
# Ross Pierschbacher  Washington Redskins        C 1995-05-05    495000
# Kelvin Harmon       Washington Redskins       WR 1996-12-15    495000
# Wes Martin          Washington Redskins        G 1996-05-09    495000
# Jimmy Moreland      Washington Redskins       CB 1995-08-26    495000
# Jeremy Reaves       Washington Redskins       SS 1996-08-29    495000
#
# [1655 rows x 4 columns]

# %%
pokemons = pd.read_csv("datas/pokemon.csv", index_col = "Pokemon").squeeze()
pokemons
# Out:
# Pokemon
# Bulbasaur      Grass / Poison
# Ivysaur        Grass / Poison
# Venusaur       Grass / Poison
# Charmander               Fire
# Charmeleon               Fire
#                     ...
# Stakataka        Rock / Steel
# Blacephalon      Fire / Ghost
# Zeraora              Electric
# Meltan                  Steel
# Melmetal                Steel
# Name: Type, Length: 809, dtype: object

# %%
def single_or_multi(type):
    if "/" in type:
        return "Multi"
    return "Single"

# %% [markdown]
# # dataframe.apply(func)

# %%
pokemons.apply(single_or_multi) # Series.apply(func) -> 데이터 각각에 함수 적용, 인자로 value값 전달
# Out:
# Pokemon
# Bulbasaur       Multi
# Ivysaur         Multi
# Venusaur        Multi
# Charmander     Single
# Charmeleon     Single
#                 ...
# Stakataka       Multi
# Blacephalon     Multi
# Zeraora        Single
# Meltan         Single
# Melmetal       Single
# Name: Type, Length: 809, dtype: object

# %%
pokemons.apply(single_or_multi).value_counts()
# Out:
# Multi     405
# Single    404
# Name: Type, dtype: int64

# %%
df = pd.DataFrame([[4, 9]]*3, columns=['A','B'])
df
# Out:
#    A  B
# 0  4  9
# 1  4  9
# 2  4  9

# %%
df.apply(np.sqrt) # np.sqrt -> 요소마다 적용되는 함수(universion function,ufunc)
# Out:
#      A    B
# 0  2.0  3.0
# 1  2.0  3.0
# 2  2.0  3.0

# %% [markdown]
# https://numpy.org/doc/stable/reference/ufuncs.html  -> ufunc모음

# %%
np.sqrt(df)
# Out:
#      A    B
# 0  2.0  3.0
# 1  2.0  3.0
# 2  2.0  3.0

# %%
df.apply(np.sum, axis = "index") # index, rows, 0 같음
# Out:
# A    12
# B    27
# dtype: int64

# %%
df.apply(lambda x: [1,2], axis =0)
# Out:
#    A  B
# 0  1  1
# 1  2  2

# %%
df.apply(lambda x: [1,2], axis=1)
# Out:
# 0    [1, 2]
# 1    [1, 2]
# 2    [1, 2]
# dtype: object

# %%
df.apply(lambda x: [1, 2], axis =1, result_type='expand')
# 리스트를 하나의 값으로 보지 않고 요소마다 컬럼으로 인식하도록 확장
# Out:
#    0  1
# 0  1  2
# 1  1  2
# 2  1  2

# %%
df.apply(lambda x: pd.Series([1,2], index = ['foo','bar']),axis = 1)
# 직접 인덱스를 지정한 시리즈를 부여
# Out:
#    foo  bar
# 0    1    2
# 1    1    2
# 2    1    2

# %%
df.apply(lambda x: [1, 2], axis = 1, result_type = "broadcast") 
# 기존 형태인 데이터 프레임으로 반환
# Out:
#    A  B
# 0  1  2
# 1  1  2
# 2  1  2

# %%
df3 = pd.DataFrame({
    'A':[1,3,4,3,4],
    'B':[2,3,1,2,3],
    'C':[1,5,2,4,5]
})
df3
# Out:
#    A  B  C
# 0  1  2  1
# 1  3  3  5
# 2  4  1  2
# 3  3  2  4
# 4  4  3  5

# %%
df3.apply(lambda x: x.max() - x.min())
# Out:
# A    4
# B    2
# C    4
# dtype: int64

# %%
df3.apply(pd.value_counts) # index는 데이터의 고유한 값(1~5), 각 요소는 해당 컬럼에서 인덱스 값이 몇 번 등장했는지
# Out:
#      A    B    C
# 1  1.0  1.0  1.0
# 2  NaN  2.0  1.0
# 3  2.0  2.0  NaN
# 4  2.0  NaN  1.0
# 5  NaN  NaN  2.0

# %%
titanic["adult/child"] = titanic.apply(lambda r: "adult" if r.age >= 20 else "child", axis = 1)
titanic.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone adult/child
# 886    man        True  NaN  Southampton    no   True       adult
# 887  woman       False    B  Southampton   yes   True       child
# 888  woman       False  NaN  Southampton    no  False       child
# 889    man        True    C    Cherbourg   yes   True       adult
# 890    man        True  NaN   Queenstown    no   True       adult

# %%
titanic["category1"] = titanic.apply(lambda r: r.sex if r.age > 20 else "child", axis = 1)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# # dataframe.fillna()

# %%
df = pd.DataFrame([[np.nan, 2, np.nan, 0],
                   [3, 4, np.nan, 1],
                   [np.nan, np.nan, np.nan, np.nan],
                   [np.nan, 3, np.nan, 4]],
                  columns = list("ABCD"))
df
# Out:
#      A    B   C    D
# 0  NaN  2.0 NaN  0.0
# 1  3.0  4.0 NaN  1.0
# 2  NaN  NaN NaN  NaN
# 3  NaN  3.0 NaN  4.0

# %%
df.fillna(0) # nan값을 0으로 채움
# Out:
#      A    B    C    D
# 0  0.0  2.0  0.0  0.0
# 1  3.0  4.0  0.0  1.0
# 2  0.0  0.0  0.0  0.0
# 3  0.0  3.0  0.0  4.0

# %%
values = {"A":0, "B":1, "C":2, "D":3}
df.fillna(value = values)
# 컬럼마다 결측치를 지정해 둔 값으로 채움
# Out:
#      A    B    C    D
# 0  0.0  2.0  2.0  0.0
# 1  3.0  4.0  2.0  1.0
# 2  0.0  1.0  2.0  3.0
# 3  0.0  3.0  2.0  4.0

# %%
values = {"A":0, "B":1, "C":2, "D":3}
df.fillna(value = values, limit = 1)
# limit -> 컬럼마다 처음 1개만 변경
# Out:
#      A    B    C    D
# 0  0.0  2.0  2.0  0.0
# 1  3.0  4.0  NaN  1.0
# 2  NaN  1.0  NaN  3.0
# 3  NaN  3.0  NaN  4.0

# %%
df2 =pd.DataFrame(np.zeros((3,4)),columns = list("ABCD"))
df.fillna(df2) 
# df의 nan값을 df2의 해당 자리 값으로 채움
# Out:
#      A    B    C    D
# 0  0.0  2.0  0.0  0.0
# 1  3.0  4.0  0.0  1.0
# 2  0.0  0.0  0.0  0.0
# 3  NaN  3.0  NaN  4.0

# %%
titanic.age = titanic.age.fillna(round(titanic.age.mean(),2))
titanic.head(20)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male  29.7      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %%
titanic.fillna({"age":round(titanic.age.mean(),2)})
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female  29.7      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
d = { 'col1':[1,2], 'col2':[3,4]}
df = pd.DataFrame(data = d)
df.dtypes
# Out:
# col1    int64
# col2    int64
# dtype: object

# %% [markdown]
# # dataframe.astype()

# %%
df.astype('int32').dtypes
# Out:
# col1    int32
# col2    int32
# dtype: object

# %%
df.astype({'col1':'int32'}).dtypes
# Out:
# col1    int32
# col2    int64
# dtype: object

# %%
employees = pd.read_csv("datas/employees.csv",parse_dates = ["Start Date"])
employees
# Out:
#      First Name  Gender Start Date    Salary   Mgmt          Team
# 0       Douglas    Male 1993-08-06       NaN   True     Marketing
# 1        Thomas    Male 1996-03-31   61933.0   True           NaN
# 2         Maria  Female        NaT  130590.0  False       Finance
# 3         Jerry     NaN 2005-03-04  138705.0   True       Finance
# 4         Larry    Male 1998-01-24  101004.0   True            IT
# ...         ...     ...        ...       ...    ...           ...
# 996     Phillip    Male 1984-01-31   42392.0  False       Finance
# 997     Russell    Male 2013-05-20   96914.0  False       Product
# 998       Larry    Male 2013-04-20   60500.0  False  Business Dev
# 999      Albert    Male 2012-05-15  129949.0   True         Sales
# 1000        NaN     NaN        NaT       NaN    NaN           NaN
#
# [1001 rows x 6 columns]

# %%
employees.dtypes
# Out:
# First Name            object
# Gender                object
# Start Date    datetime64[ns]
# Salary               float64
# Mgmt                  object
# Team                  object
# dtype: object

# %%
employees = employees.astype({"Gender":"category", "Mgmt":"boolean"})

# %%
employees
# Out:
#      First Name  Gender Start Date    Salary   Mgmt          Team
# 0       Douglas    Male 1993-08-06       NaN   True     Marketing
# 1        Thomas    Male 1996-03-31   61933.0   True           NaN
# 2         Maria  Female        NaT  130590.0  False       Finance
# 3         Jerry     NaN 2005-03-04  138705.0   True       Finance
# 4         Larry    Male 1998-01-24  101004.0   True            IT
# ...         ...     ...        ...       ...    ...           ...
# 996     Phillip    Male 1984-01-31   42392.0  False       Finance
# 997     Russell    Male 2013-05-20   96914.0  False       Product
# 998       Larry    Male 2013-04-20   60500.0  False  Business Dev
# 999      Albert    Male 2012-05-15  129949.0   True         Sales
# 1000        NaN     NaN        NaT       NaN   <NA>           NaN
#
# [1001 rows x 6 columns]

# %%
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  933 non-null    object
#  1   Gender      854 non-null    category
#  2   Start Date  999 non-null    datetime64[ns]
#  3   Salary      999 non-null    float64
#  4   Mgmt        933 non-null    boolean
#  5   Team        957 non-null    object
# dtypes: boolean(1), category(1), datetime64[ns](1), float64(1), object(2)
# memory usage: 34.5+ KB

# %%
employees = employees.fillna({"Salary": 0})

# %%
sum( (employees.Salary - employees.Salary.astype(int))>0)

# %%
employees.Salary = employees.Salary.astype(int)
employees
# Out:
#      First Name  Gender Start Date  Salary   Mgmt          Team
# 0       Douglas    Male 1993-08-06       0   True     Marketing
# 1        Thomas    Male 1996-03-31   61933   True           NaN
# 2         Maria  Female        NaT  130590  False       Finance
# 3         Jerry     NaN 2005-03-04  138705   True       Finance
# 4         Larry    Male 1998-01-24  101004   True            IT
# ...         ...     ...        ...     ...    ...           ...
# 996     Phillip    Male 1984-01-31   42392  False       Finance
# 997     Russell    Male 2013-05-20   96914  False       Product
# 998       Larry    Male 2013-04-20   60500  False  Business Dev
# 999      Albert    Male 2012-05-15  129949   True         Sales
# 1000        NaN     NaN        NaT       0   <NA>           NaN
#
# [1001 rows x 6 columns]

# %%
employees.dtypes
# Out:
# First Name            object
# Gender              category
# Start Date    datetime64[ns]
# Salary                 int32
# Mgmt                 boolean
# Team                  object
# dtype: object

# %%
employees.nunique()
# Out:
# First Name    200
# Gender          2
# Start Date    971
# Salary        995
# Mgmt            2
# Team           10
# dtype: int64

# %%
employees = employees.astype({"Gender":"category","Team":"category"})
# 범주화, bool타입 으로 변경하면 메모리 절약

# %%
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  933 non-null    object
#  1   Gender      854 non-null    category
#  2   Start Date  999 non-null    datetime64[ns]
#  3   Salary      1001 non-null   int32
#  4   Mgmt        933 non-null    boolean
#  5   Team        957 non-null    category
# dtypes: boolean(1), category(2), datetime64[ns](1), int32(1), object(1)
# memory usage: 24.1+ KB

# %%
titanic["category2"]=titanic.sex + titanic.age.astype(str)

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %% [markdown]
# # pd.cut(데이터, 범주, 라벨)

# %%
ages = [0, 2, 10, 21, 23, 37, 31, 61, 20, 41, 32 ,101]
bins = [1, 20, 30, 50, 70, 100]
labels = ["미성년자", "청년", "장년", "중년", "노년"]
cats = pd.cut(ages, bins, labels = labels)
cats
# Out:
# [NaN, '미성년자', '미성년자', '청년', '청년', ..., '중년', '미성년자', '장년', '장년', NaN]
# Length: 12
# Categories (5, object): ['미성년자' < '청년' < '장년' < '중년' < '노년']

# %%
type(cats)
# Out:
# pandas.core.arrays.categorical.Categorical

# %%
cats.categories
# Out:
# Index(['미성년자', '청년', '장년', '중년', '노년'], dtype='object')

# %%
cats.codes
# Out:
# array([-1,  0,  0,  1,  1,  2,  2,  3,  0,  2,  2, -1], dtype=int8)

# %%
df4 = pd.DataFrame(ages, columns= ["ages"])
df4["age_cat"] = pd.cut(df4. ages, bins, labels= labels)
df4
# Out:
#     ages age_cat
# 0      0     NaN
# 1      2    미성년자
# 2     10    미성년자
# 3     21      청년
# 4     23      청년
# 5     37      장년
# 6     31      장년
# 7     61      중년
# 8     20    미성년자
# 9     41      장년
# 10    32      장년
# 11   101     NaN

# %%
df4.dtypes
# Out:
# ages          int64
# age_cat    category
# dtype: object

# %%
df4["age_cat"].astype(str) +df4["ages"].astype(str)
# Out:
# 0       nan0
# 1      미성년자2
# 2     미성년자10
# 3       청년21
# 4       청년23
# 5       장년37
# 6       장년31
# 7       중년61
# 8     미성년자20
# 9       장년41
# 10      장년32
# 11    nan101
# dtype: object

# %%
data = np.random.randn(1000)
cats = pd.qcut(data, 4, labels= ['Q1','Q2','Q3','Q4'])
cats
# Out:
# ['Q4', 'Q1', 'Q3', 'Q4', 'Q4', ..., 'Q4', 'Q1', 'Q2', 'Q3', 'Q4']
# Length: 1000
# Categories (4, object): ['Q1' < 'Q2' < 'Q3' < 'Q4']

# %%
pd.value_counts(cats)
# Out:
# Q1    250
# Q2    250
# Q3    250
# Q4    250
# dtype: int64

# %%
bins = [1, 20, 30, 50, 70, 100]
labels = ["미성년자", "청년", "장년", "중년", "노년"]
pd.cut(titanic.age, bins, labels=labels).value_counts(normalize=True) # normalisze -> 값의 비율
# Out:
# 장년      0.344286
# 청년      0.328571
# 미성년자    0.235714
# 중년      0.084286
# 노년      0.007143
# Name: age, dtype: float64

# %%
pd.cut(titanic.age, bins, labels=labels).value_counts() / sum(pd.cut(titanic.age, bins, labels=labels).value_counts())
# Out:
# 장년      0.344286
# 청년      0.328571
# 미성년자    0.235714
# 중년      0.084286
# 노년      0.007143
# Name: age, dtype: float64

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
#  15  category2    891 non-null    object
#  16  category3    700 non-null    category
# dtypes: bool(2), category(3), float64(2), int64(4), object(6)
# ...

# %%
titanic.age.fillna(titanic.age.mean(), inplace = True)
bins = [1, 20, 30, 50, 70, 100]
labels = ["미성년자", "청년", "장년", "중년", "노년"]

titanic["연령층"] = pd.cut(titanic.age, bins = bins , labels = labels)
titanic["category3"] = titanic.apply(lambda r: "미성년자" if r.age<20 else r.연령층 
                                     + ("남성" if r.sex == "male" else "여성"), axis=1)
titanic
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
#       class    who  adult_male deck  embark_town alive  alone   category2  \
# ...

# %% [markdown]
# # dataframe.set index(),reset index()

# %%
np.random.seed(0)
df1= pd.DataFrame(np.vstack([list('ABCDE'),
                             np.round(np.random.rand(3,5),2)]).T,
                  columns = ["C1","C2","C3","C4"])
df1
# Out:
#   C1    C2    C3    C4
# 0  A  0.55  0.65  0.79
# 1  B  0.72  0.44  0.53
# 2  C   0.6  0.89  0.57
# 3  D  0.54  0.96  0.93
# 4  E  0.42  0.38  0.07

# %%
df2 = df1.set_index("C1") # 특정한 컬럼을 인덱스로 설정, 기존의 인덱스는 없어짐
df2
# Out:
#       C2    C3    C4
# C1
# A   0.55  0.65  0.79
# B   0.72  0.44  0.53
# C    0.6  0.89  0.57
# D   0.54  0.96  0.93
# E   0.42  0.38  0.07

# %%
df2.set_index("C2")
# Out:
#         C3    C4
# C2
# 0.55  0.65  0.79
# 0.72  0.44  0.53
# 0.6   0.89  0.57
# 0.54  0.96  0.93
# 0.42  0.38  0.07

# %%
df2.reset_index() # 사라진 인덱스를 복구
# Out:
#   C1    C2    C3    C4
# 0  A  0.55  0.65  0.79
# 1  B  0.72  0.44  0.53
# 2  C   0.6  0.89  0.57
# 3  D  0.54  0.96  0.93
# 4  E  0.42  0.38  0.07

# %%
df2 = df1.set_index("C1")
df2
# Out:
#       C2    C3    C4
# C1
# A   0.55  0.65  0.79
# B   0.72  0.44  0.53
# C    0.6  0.89  0.57
# D   0.54  0.96  0.93
# E   0.42  0.38  0.07

# %%
df2.reset_index(drop= True) # 바뀐 인덱스를 버리고 기존의 인덱스를 가져옴
# Out:
#      C2    C3    C4
# 0  0.55  0.65  0.79
# 1  0.72  0.44  0.53
# 2   0.6  0.89  0.57
# 3  0.54  0.96  0.93
# 4  0.42  0.38  0.07

# %%
nfl = pd.read_csv("datas/nfl.csv", parse_dates=["Birthday"], index_col=["Name"])
nfl
# Out:
#                                     Team Position   Birthday   Salary
# Name
# Tremon Smith         Philadelphia Eagles       RB 1996-07-20   570000
# Shawn Williams        Cincinnati Bengals       SS 1991-05-13  3500000
# Adam Butler         New England Patriots       DT 1994-04-12   645000
# Derek Wolfe               Denver Broncos       DE 1990-02-24  8000000
# Jake Ryan           Jacksonville Jaguars      OLB 1992-02-27  1000000
# ...                                  ...      ...        ...      ...
# Bashaud Breeland      Kansas City Chiefs       CB 1992-01-30   805000
# Craig James          Philadelphia Eagles       CB 1996-04-29   570000
# Jonotthan Harrison         New York Jets        C 1991-08-25  1500000
# Chuma Edoga                New York Jets       OT 1997-05-25   495000
# Tajae Sharpe            Tennessee Titans       WR 1994-12-23  2025000
#
# [1655 rows x 4 columns]

# %%
a= nfl.reset_index().set_index("Team").loc["New York Jets"].nsmallest(1,"Birthday")
a
# Out:
#                     Name                  Team Position   Birthday   Salary
# 0           Tremon Smith   Philadelphia Eagles       RB 1996-07-20   570000
# 1         Shawn Williams    Cincinnati Bengals       SS 1991-05-13  3500000
# 2            Adam Butler  New England Patriots       DT 1994-04-12   645000
# 3            Derek Wolfe        Denver Broncos       DE 1990-02-24  8000000
# 4              Jake Ryan  Jacksonville Jaguars      OLB 1992-02-27  1000000
# ...                  ...                   ...      ...        ...      ...
# 1650    Bashaud Breeland    Kansas City Chiefs       CB 1992-01-30   805000
# 1651         Craig James   Philadelphia Eagles       CB 1996-04-29   570000
# 1652  Jonotthan Harrison         New York Jets        C 1991-08-25  1500000
# 1653         Chuma Edoga         New York Jets       OT 1997-05-25   495000
# 1654        Tajae Sharpe      Tennessee Titans       WR 1994-12-23  2025000
#
# [1655 rows x 5 columns]

# %%
score = pd.DataFrame({"이름": ["일식","이식","삼식","사식", "오식"],
                     "국어": [60, 70, 90, 80, 100],
                     "영어": [70,86,82,88,100],
                     "수학": [65,82,85,90,100]})
score = score.set_index("이름")
score = score.reset_index("이름")
score
# Out:
#    이름   국어   영어   수학
# 0  일식   60   70   65
# 1  이식   70   86   82
# 2  삼식   90   82   85
# 3  사식   80   88   90
# 4  오식  100  100  100

# %% [markdown]
# # dropna()

# %%
employees = pd.read_csv("datas/employees.csv", parse_dates = ["Start Date"])

# %%
employees.dropna() # 행에 결측치가 하나라도 있으면 해당 행 삭제
# Out:
#     First Name  Gender Start Date    Salary   Mgmt          Team
# 4        Larry    Male 1998-01-24  101004.0   True            IT
# 5       Dennis    Male 1987-04-18  115163.0  False         Legal
# 6         Ruby  Female 1987-08-17   65476.0   True       Product
# 8       Angela  Female 2005-11-22   95570.0   True   Engineering
# 9      Frances  Female 2002-08-08  139852.0   True  Business Dev
# ..         ...     ...        ...       ...    ...           ...
# 994     George    Male 2013-06-21   98874.0   True     Marketing
# 996    Phillip    Male 1984-01-31   42392.0  False       Finance
# 997    Russell    Male 2013-05-20   96914.0  False       Product
# 998      Larry    Male 2013-04-20   60500.0  False  Business Dev
# 999     Albert    Male 2012-05-15  129949.0   True         Sales
#
# [761 rows x 6 columns]

# %%
employees.dropna(how = "all") # 행의 모든 값이 결측치인 경우만 삭제
# Out:
#     First Name  Gender Start Date    Salary   Mgmt          Team
# 0      Douglas    Male 1993-08-06       NaN   True     Marketing
# 1       Thomas    Male 1996-03-31   61933.0   True           NaN
# 2        Maria  Female        NaT  130590.0  False       Finance
# 3        Jerry     NaN 2005-03-04  138705.0   True       Finance
# 4        Larry    Male 1998-01-24  101004.0   True            IT
# ..         ...     ...        ...       ...    ...           ...
# 995      Henry     NaN 2014-11-23  132483.0  False  Distribution
# 996    Phillip    Male 1984-01-31   42392.0  False       Finance
# 997    Russell    Male 2013-05-20   96914.0  False       Product
# 998      Larry    Male 2013-04-20   60500.0  False  Business Dev
# 999     Albert    Male 2012-05-15  129949.0   True         Sales
#
# [1000 rows x 6 columns]

# %%
employees.dropna(how = "any")
# Out:
#     First Name  Gender Start Date    Salary   Mgmt          Team
# 4        Larry    Male 1998-01-24  101004.0   True            IT
# 5       Dennis    Male 1987-04-18  115163.0  False         Legal
# 6         Ruby  Female 1987-08-17   65476.0   True       Product
# 8       Angela  Female 2005-11-22   95570.0   True   Engineering
# 9      Frances  Female 2002-08-08  139852.0   True  Business Dev
# ..         ...     ...        ...       ...    ...           ...
# 994     George    Male 2013-06-21   98874.0   True     Marketing
# 996    Phillip    Male 1984-01-31   42392.0  False       Finance
# 997    Russell    Male 2013-05-20   96914.0  False       Product
# 998      Larry    Male 2013-04-20   60500.0  False  Business Dev
# 999     Albert    Male 2012-05-15  129949.0   True         Sales
#
# [761 rows x 6 columns]

# %%
employees.loc[employees.Gender.isnull()] # 지울 값 조회
# Out:
#      First Name Gender Start Date    Salary   Mgmt          Team
# 3         Jerry    NaN 2005-03-04  138705.0   True       Finance
# 20         Lois    NaN 1995-04-22   64714.0   True         Legal
# 22       Joshua    NaN 2012-03-08   90816.0   True            IT
# 27        Scott    NaN 1991-07-11  122367.0  False         Legal
# 31        Joyce    NaN 2005-02-20   88657.0  False       Product
# ...         ...    ...        ...       ...    ...           ...
# 972      Victor    NaN 2006-07-28   76381.0   True         Sales
# 985     Stephen    NaN 1983-07-10   85668.0  False         Legal
# 989      Justin    NaN 1991-02-10   38344.0  False         Legal
# 995       Henry    NaN 2014-11-23  132483.0  False  Distribution
# 1000        NaN    NaN        NaT       NaN    NaN           NaN
#
# [147 rows x 6 columns]

# %%
employees.dropna(subset = ["Gender"]) # gender가 nan값인 행만 지움
# Out:
#     First Name  Gender Start Date    Salary   Mgmt          Team
# 0      Douglas    Male 1993-08-06       NaN   True     Marketing
# 1       Thomas    Male 1996-03-31   61933.0   True           NaN
# 2        Maria  Female        NaT  130590.0  False       Finance
# 4        Larry    Male 1998-01-24  101004.0   True            IT
# 5       Dennis    Male 1987-04-18  115163.0  False         Legal
# ..         ...     ...        ...       ...    ...           ...
# 994     George    Male 2013-06-21   98874.0   True     Marketing
# 996    Phillip    Male 1984-01-31   42392.0  False       Finance
# 997    Russell    Male 2013-05-20   96914.0  False       Product
# 998      Larry    Male 2013-04-20   60500.0  False  Business Dev
# 999     Albert    Male 2012-05-15  129949.0   True         Sales
#
# [854 rows x 6 columns]

# %%
cond1 = employees["Start Date"].isnull()
cond2 = employees["Salary"].isnull()
print(f"cond1: {cond1.sum()}, cond2: {cond2.sum()}")
# Out:
# cond1: 2, cond2: 2

# %%
employees[cond1]
# Out:
#      First Name  Gender Start Date    Salary   Mgmt     Team
# 2         Maria  Female        NaT  130590.0  False  Finance
# 1000        NaN     NaN        NaT       NaN    NaN      NaN

# %%
employees[cond2]
# Out:
#      First Name Gender Start Date  Salary  Mgmt       Team
# 0       Douglas   Male 1993-08-06     NaN  True  Marketing
# 1000        NaN    NaN        NaT     NaN   NaN        NaN

# %%
employees[cond1 | cond2] # '|' -> or연산
# Out:
#      First Name  Gender Start Date    Salary   Mgmt       Team
# 0       Douglas    Male 1993-08-06       NaN   True  Marketing
# 2         Maria  Female        NaT  130590.0  False    Finance
# 1000        NaN     NaN        NaT       NaN    NaN        NaN

# %%
employees.dropna(subset = ["Start Date", "Salary"])
# Out:
#     First Name  Gender Start Date    Salary   Mgmt          Team
# 1       Thomas    Male 1996-03-31   61933.0   True           NaN
# 3        Jerry     NaN 2005-03-04  138705.0   True       Finance
# 4        Larry    Male 1998-01-24  101004.0   True            IT
# 5       Dennis    Male 1987-04-18  115163.0  False         Legal
# 6         Ruby  Female 1987-08-17   65476.0   True       Product
# ..         ...     ...        ...       ...    ...           ...
# 995      Henry     NaN 2014-11-23  132483.0  False  Distribution
# 996    Phillip    Male 1984-01-31   42392.0  False       Finance
# 997    Russell    Male 2013-05-20   96914.0  False       Product
# 998      Larry    Male 2013-04-20   60500.0  False  Business Dev
# 999     Albert    Male 2012-05-15  129949.0   True         Sales
#
# [998 rows x 6 columns]

# %%
employees[employees.notnull().sum(axis=1) >=4]
# Out:
#     First Name  Gender Start Date    Salary   Mgmt          Team
# 0      Douglas    Male 1993-08-06       NaN   True     Marketing
# 1       Thomas    Male 1996-03-31   61933.0   True           NaN
# 2        Maria  Female        NaT  130590.0  False       Finance
# 3        Jerry     NaN 2005-03-04  138705.0   True       Finance
# 4        Larry    Male 1998-01-24  101004.0   True            IT
# ..         ...     ...        ...       ...    ...           ...
# 995      Henry     NaN 2014-11-23  132483.0  False  Distribution
# 996    Phillip    Male 1984-01-31   42392.0  False       Finance
# 997    Russell    Male 2013-05-20   96914.0  False       Product
# 998      Larry    Male 2013-04-20   60500.0  False  Business Dev
# 999     Albert    Male 2012-05-15  129949.0   True         Sales
#
# [985 rows x 6 columns]

# %%
employees.dropna(how="any", thresh = 4)
# notnull이 4개 이상인 행만 보존
# Out:
#     First Name  Gender Start Date    Salary   Mgmt          Team
# 0      Douglas    Male 1993-08-06       NaN   True     Marketing
# 1       Thomas    Male 1996-03-31   61933.0   True           NaN
# 2        Maria  Female        NaT  130590.0  False       Finance
# 3        Jerry     NaN 2005-03-04  138705.0   True       Finance
# 4        Larry    Male 1998-01-24  101004.0   True            IT
# ..         ...     ...        ...       ...    ...           ...
# 995      Henry     NaN 2014-11-23  132483.0  False  Distribution
# 996    Phillip    Male 1984-01-31   42392.0  False       Finance
# 997    Russell    Male 2013-05-20   96914.0  False       Product
# 998      Larry    Male 2013-04-20   60500.0  False  Business Dev
# 999     Albert    Male 2012-05-15  129949.0   True         Sales
#
# [985 rows x 6 columns]

# %% [markdown]
# # duplicated()

# %%
employees["Team"].head()
# Out:
# 0    Marketing
# 1          NaN
# 2      Finance
# 3      Finance
# 4           IT
# Name: Team, dtype: object

# %%
employees["Team"].duplicated().head()
# 순차적으로 값을 확인하며, 이전에 한번이라도 등장한 값에 대해서는 True
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# Name: Team, dtype: bool

# %%
employees["Team"].duplicated(keep = "last") 
# 가장 마지막에 나온 하나에 대해서만 False
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# 15    True
# 16    True
# 17    True
# 18    True
# 19    True
# Name: Team, dtype: bool

# %%
first_one_in_team = ~ employees["Team"].duplicated()
employees[first_one_in_team]
# Out:
#    First Name  Gender Start Date    Salary   Mgmt          Team
# 0     Douglas    Male 1993-08-06       NaN   True     Marketing
# 1      Thomas    Male 1996-03-31   61933.0   True           NaN
# 2       Maria  Female        NaT  130590.0  False       Finance
# 4       Larry    Male 1998-01-24  101004.0   True            IT
# 5      Dennis    Male 1987-04-18  115163.0  False         Legal
# 6        Ruby  Female 1987-08-17   65476.0   True       Product
# 8      Angela  Female 2005-11-22   95570.0   True   Engineering
# 9     Frances  Female 2002-08-08  139852.0   True  Business Dev
# 12    Brandon    Male 1980-12-01  112807.0   True            HR
# 13       Gary    Male 2008-01-27  109831.0  False         Sales
# 40    Michael    Male 2008-10-10   99283.0   True  Distribution

# %%
employees.drop_duplicates() # 각 행별로 모든 열의 값이 중복될 때만 제거
# Out:
#      First Name  Gender Start Date    Salary   Mgmt          Team
# 0       Douglas    Male 1993-08-06       NaN   True     Marketing
# 1        Thomas    Male 1996-03-31   61933.0   True           NaN
# 2         Maria  Female        NaT  130590.0  False       Finance
# 3         Jerry     NaN 2005-03-04  138705.0   True       Finance
# 4         Larry    Male 1998-01-24  101004.0   True            IT
# ...         ...     ...        ...       ...    ...           ...
# 996     Phillip    Male 1984-01-31   42392.0  False       Finance
# 997     Russell    Male 2013-05-20   96914.0  False       Product
# 998       Larry    Male 2013-04-20   60500.0  False  Business Dev
# 999      Albert    Male 2012-05-15  129949.0   True         Sales
# 1000        NaN     NaN        NaT       NaN    NaN           NaN
#
# [1001 rows x 6 columns]

# %%
employees.drop_duplicates(subset = ["Team"]) # 중복을 확인할 특정 열 지정
# Out:
#    First Name  Gender Start Date    Salary   Mgmt          Team
# 0     Douglas    Male 1993-08-06       NaN   True     Marketing
# 1      Thomas    Male 1996-03-31   61933.0   True           NaN
# 2       Maria  Female        NaT  130590.0  False       Finance
# 4       Larry    Male 1998-01-24  101004.0   True            IT
# 5      Dennis    Male 1987-04-18  115163.0  False         Legal
# 6        Ruby  Female 1987-08-17   65476.0   True       Product
# 8      Angela  Female 2005-11-22   95570.0   True   Engineering
# 9     Frances  Female 2002-08-08  139852.0   True  Business Dev
# 12    Brandon    Male 1980-12-01  112807.0   True            HR
# 13       Gary    Male 2008-01-27  109831.0  False         Sales
# 40    Michael    Male 2008-10-10   99283.0   True  Distribution

# %%
employees.drop_duplicates(subset = ["Team"], keep = "last") 
# 마지막 고유값
# Out:
#      First Name  Gender Start Date    Salary   Mgmt          Team
# 988       Alice  Female 2004-10-05   47638.0  False            HR
# 989      Justin     NaN 1991-02-10   38344.0  False         Legal
# 990       Robin  Female 1987-07-24  100765.0   True            IT
# 993        Tina  Female 1997-05-15   56450.0   True   Engineering
# 994      George    Male 2013-06-21   98874.0   True     Marketing
# 995       Henry     NaN 2014-11-23  132483.0  False  Distribution
# 996     Phillip    Male 1984-01-31   42392.0  False       Finance
# 997     Russell    Male 2013-05-20   96914.0  False       Product
# 998       Larry    Male 2013-04-20   60500.0  False  Business Dev
# 999      Albert    Male 2012-05-15  129949.0   True         Sales
# 1000        NaN     NaN        NaT       NaN    NaN           NaN

# %%
employees.drop_duplicates(subset = ["First Name"], keep = False)
# 중복이 하나라도 있다면 제거
# Out:
#     First Name  Gender Start Date    Salary   Mgmt          Team
# 5       Dennis    Male 1987-04-18  115163.0  False         Legal
# 8       Angela  Female 2005-11-22   95570.0   True   Engineering
# 33        Jean  Female 1993-12-18  119082.0  False  Business Dev
# 190      Carol  Female 1996-03-19   57783.0  False       Finance
# 291      Tammy  Female 1984-11-11  132839.0   True            IT
# 495     Eugene    Male 1984-05-24   81077.0  False         Sales
# 688      Brian    Male 2007-04-07   93901.0   True         Legal
# 832      Keith    Male 2003-02-12  120672.0  False         Legal
# 887      David    Male 2009-12-05   92242.0  False         Legal

# %%
name_is_douglas = employees["First Name"] == "Douglas"
is_male = employees["Gender"] == "Male"
employees[name_is_douglas&is_male]
# Out:
#     First Name Gender Start Date    Salary   Mgmt         Team
# 0      Douglas   Male 1993-08-06       NaN   True    Marketing
# 217    Douglas   Male 1999-09-03   83341.0   True           IT
# 322    Douglas   Male 2002-01-08   41428.0  False      Product
# 835    Douglas   Male 2007-08-04  132175.0  False  Engineering

# %%
employees.drop_duplicates(subset = ["Gender","Team"])
# 지정한 모든 열이 중복되는 값만 제거
# Out:
#     First Name  Gender Start Date    Salary   Mgmt          Team
# 0      Douglas    Male 1993-08-06       NaN   True     Marketing
# 1       Thomas    Male 1996-03-31   61933.0   True           NaN
# 2        Maria  Female        NaT  130590.0  False       Finance
# 3        Jerry     NaN 2005-03-04  138705.0   True       Finance
# 4        Larry    Male 1998-01-24  101004.0   True            IT
# 5       Dennis    Male 1987-04-18  115163.0  False         Legal
# 6         Ruby  Female 1987-08-17   65476.0   True       Product
# 8       Angela  Female 2005-11-22   95570.0   True   Engineering
# 9      Frances  Female 2002-08-08  139852.0   True  Business Dev
# 10      Louise  Female 1980-08-12   63241.0   True           NaN
# 11       Julie  Female 1997-10-26  102508.0   True         Legal
# 12     Brandon    Male 1980-12-01  112807.0   True            HR
# 13        Gary    Male 2008-01-27  109831.0  False         Sales
# ...
